# %%
import blender_plot as bp
import numpy as np
import torch

# %%
data = torch.load("samples/reconstructions.pt").numpy()
data.shape
# Out:
# (9, 2048, 3)

# %%
s = bp.DefaultScene()

# %%
s.scatter(data[0], alpha=0.5)

# %%
s.render("plots/renders/reconstruction.png", resolution=(1000, 1000), samples=128)
# Out:
# Fra:1 Mem:144.73M (Peak 144.73M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Synchronizing object | mesh.004
# Fra:1 Mem:147.23M (Peak 147.23M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Synchronizing object | Plane
# Fra:1 Mem:157.01M (Peak 158.32M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Initializing
# Fra:1 Mem:157.01M (Peak 158.32M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Waiting for render to start
# Fra:1 Mem:157.01M (Peak 158.32M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:157.01M (Peak 158.32M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Updating Scene
# Fra:1 Mem:157.01M (Peak 158.32M) | Time:00:00.02 | Mem:0.00M, Peak:0.00M | DefaultScene, ViewLayer | Updating Shaders
# ...

# %%
s.clear()
